# %%
import scipy.io
import cv2
import pandas as pd
import os
import random 
import numpy as np
import json
import math

# %%
def parseVideoName(video_name):
    video_name = video_name.replace('.avi', '')
    first_part,second_part = video_name.split(',')
    video_type, num_targets = first_part.rsplit('_', 1)
    videos_info = second_part.split('_')
    
    parsed_data = {
        'video_name': video_name,
        'target_name': second_part,
        'video_type': video_type,
        'num_targets': int(num_targets),
        'first_video': int(videos_info[0]),
        'second_video': int(videos_info[1]),
        'first_start_frame': int(videos_info[2]),
        'second_start_frame': int(videos_info[3]),
        'first_rotation': float(videos_info[4]),
        'second_rotation': float(videos_info[5])
    }
    
    return parsed_data
    
def generateRandomColor():
    return (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))

def processTrialsVideos(file_path):
    df = pd.read_csv(file_path)
    parsed_rows = []
    
    for index, row in df.iterrows():
        video_name = row['videoName']
        parsed_data = parseVideoName(video_name)
        parsed_data['firstTargets'] = row['firstTargets']
        parsed_data['secondTargets'] = row['secondTargets']
        parsed_rows.append(parsed_data)
        # parsed_rows.append(1)
    return pd.DataFrame(parsed_rows)
    
def loadMatFile():
    root_folder = 'GazeMat'
    test_subs = ['sub11', 'sub21', 'sub31', 'sub41', 'sub51']

    data = {}
    
    for sub_dir in os.listdir(root_folder):
        if sub_dir in test_subs:
            mat_file_path = os.path.join(root_folder, sub_dir, '40.mat')
            if os.path.exists(mat_file_path):
                mat_data = scipy.io.loadmat(mat_file_path)
                data[sub_dir] = mat_data["extractedData"]
            else:
                print(f"{mat_file_path} does not exist.")
    print("Data loaded successfully.")
    return data


def loadShapeFishPoints(videoName,frame):
    print(frame)
    json_filename = f'img{frame:03d}.json'
    json_path = os.path.join('./jsons', str(videoName), json_filename)

    if not os.path.exists(json_path):
        raise FileNotFoundError(f"JSON file not found: {json_path}")

    with open(json_path, 'r') as json_file:
        data = json.load(json_file)
    
    return data.get('shapes', [])

def getTargetsFromJson(shapes,targets):
    if not isinstance(targets, (list, tuple)):
        targets = [targets]
    
    target_digits = set()
    for target in targets:
        if isinstance(target, int):
            target_digits.update(str(target))
        else:
            raise ValueError("Targets should be integers or lists/tuples of integers")

    filtered_shapes = [shape for shape in shapes if shape['label'] in target_digits]
    
    return filtered_shapes

def getTotalShapeFirst(shapeInfo,baseFrame):
    firstFrame = shapeInfo['firstStart'] + baseFrame
    firstTargets = shapeInfo['firstTargets']
    shapes_video1 = loadShapeFishPoints(shapeInfo['first'], firstFrame)
    return getTargetsFromJson(shapes_video1,firstTargets)
    
def getTotalShapeSecond(shapeInfo,baseFrame):
    secondFrame = shapeInfo['secondStart'] + baseFrame
    secondTargets = shapeInfo['secondTargets']
    shapes_video2 = loadShapeFishPoints(shapeInfo['second'], secondFrame)
    merged_shapes = getTargetsFromJson(shapes_video2,secondTargets)
    return merged_shapes

def generateSubjectName(subIndex):
    number_part = subIndex[3:]
    modified_number = number_part[:-1] if len(number_part) > 1 else '0'
    return f'sub{modified_number}'

def getVideoInfo(video):
    fps = video.get(cv2.CAP_PROP_FPS)
    width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
    # num_frames = int(mainVideo.get(cv2.CAP_PROP_FRAME_COUNT))
    return fps, width, height 

def createOutputVideo(video,name):
    output_gaze_videos = 'test'
    os.makedirs(output_gaze_videos, exist_ok=True)
    fps, width, height = getVideoInfo(video)
    
    output_gaze_videos_path = os.path.join(output_gaze_videos, name + '.avi')
    output_video = cv2.VideoWriter(output_gaze_videos_path, cv2.VideoWriter_fourcc(*'XVID'), fps, (width, height))
    return output_video

def getSubjectColor(subject):
    if subject not in subject_colors:
        subject_colors[subject] = generateRandomColor()
    return subject_colors[subIndex]

def mapPointsOnFrame(frame):
    return round(frame * (7798 / 110))

def openVideo(video):
    trialVideo = cv2.VideoCapture(os.path.join('./videos', video['video_type'], video['target_name'] + '.avi'))
    
    if not trialVideo.isOpened():
        raise ValueError(f"Unable to open video file: {os.path.join('./videos', video['video_type'], video['target_name'] + '.avi')}")
    
    return trialVideo

def generateXPoints(x):
    scale_x = 660 / 1920
    return int(x * scale_x)

def generateYPoints(y):
    scale_y = 660 / 1080
    return int(y * scale_y)

def rotate_frame(frame, angle):
    (h, w) = frame.shape[:2]
    center = (330, 330)
    
    # Create the rotation matrix
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    
    # Perform the rotation
    rotated_frame = cv2.warpAffine(frame, M, (w, h))
    return rotated_frame

# %%
subjects = loadMatFile()
subject_colors = {}
# Out:
# Data loaded successfully.

# %%
videoData = processTrialsVideos('./sub21.csv').iloc[1:2]
videoData
# Out:
#                 video_name         target_name video_type  num_targets  \
# 1  NO_2,1_10_119_344_45_90  1_10_119_344_45_90         NO            2
#
#    first_video  second_video  first_start_frame  second_start_frame  \
# 1            1            10                119                 344
#
#    first_rotation  second_rotation  firstTargets  secondTargets
# 1            45.0             90.0             3              4

# %%
def draw_shapes(frame, shapes):
    for shape in shapes:
        points = shape['points']
        # Check if points are empty
        if not points:
            continue
        
        # Calibrate points
        calibrated_points = [(generateXPoints(x), generateYPoints(y)) for x, y in points]
        # Convert to NumPy array and reshape
        np_points = np.array(calibrated_points, dtype=np.int32).reshape((-1, 1, 2))
        
        # Debug print
        print(f"Drawing shape with points: {np_points}")

        # Ensure np_points is valid
        if np_points.size == 0:
            continue
        
        # Draw the shape
        cv2.polylines(frame, [np_points], isClosed=True, color=(0, 0, 225), thickness=2)
        cv2.fillPoly(frame, [np_points], color=(0, 0, 225))

# %%
videoList = []
trialNumber  = 1

for index, video in videoData.iterrows():
    try:
        
        open_video = openVideo(video)
        output_video = createOutputVideo(open_video,video.video_name)
        
        frame_idx = 0

        while True:
            ret, frame = open_video.read()
            if not ret:
                break  

            shapeInfo = {
                'first': video.first_video,
                'second': video.second_video,
                'firstTargets': video.firstTargets,
                'secondTargets': video.secondTargets,
                'firstStart': video.first_start_frame,
                'secondStart': video.second_start_frame
            }

            shapeFirst = getTotalShapeFirst(shapeInfo, frame_idx)
            shapeSecond = getTotalShapeSecond(shapeInfo, frame_idx)
            
            # Rotate the frame for the first and second videos
            rotated_frame_first = rotate_frame(frame, video.first_rotation)
            rotated_frame_second = rotate_frame(frame, video.second_rotation)

            # Draw shapes for the first video
            print("Processing shapes from first video")
            draw_shapes(rotated_frame_first, shapeFirst)

            # Draw shapes for the second video
            print("Processing shapes from second video")
            draw_shapes(rotated_frame_second, shapeSecond)

            # Optionally, choose which rotated frame to save
            # For example, save the first rotated frame
            resized_frame_first = cv2.resize(rotated_frame_first, (660, 660))
            output_video.write(resized_frame_first)
            frame_idx += 1
        
        trialNumber += 1
        
    except Exception as e:
        print(f"An error occurred while processing video at index {index}: {e}")

    finally:
        # Release everything
        if 'open_video' in locals() and open_video.isOpened():
            open_video.release()
        if 'output_video' in locals():
            output_video.release()
        cv2.destroyAllWindows()
# Out:
# 119
# 344
# Processing shapes from first video
# Drawing shape with points: [[[244 265]]
#
#  [[239 255]]
#
#  [[232 271]]
#
#  [[227 281]]
#
#  [[222 293]]
#
#  [[214 315]]
#
#  [[223 297]]
#
#  [[229 286]]
#
#  [[234 275]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 80 378]]
#
#  [[ 82 387]]
#
#  [[118 344]]]
# 120
# 345
# Processing shapes from first video
# Drawing shape with points: [[[244 265]]
#
#  [[239 255]]
#
#  [[232 271]]
#
#  [[227 281]]
#
#  [[222 293]]
#
#  [[214 315]]
#
#  [[223 297]]
#
#  [[229 286]]
#
#  [[234 275]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 80 378]]
#
#  [[ 82 387]]
#
#  [[118 344]]]
# 121
# 346
# Processing shapes from first video
# Drawing shape with points: [[[244 265]]
#
#  [[239 255]]
#
#  [[232 271]]
#
#  [[227 281]]
#
#  [[222 293]]
#
#  [[214 315]]
#
#  [[223 297]]
#
#  [[229 286]]
#
#  [[234 275]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 80 378]]
#
#  [[ 82 387]]
#
#  [[118 344]]]
# 122
# 347
# Processing shapes from first video
# Drawing shape with points: [[[243 262]]
#
#  [[237 257]]
#
#  [[233 274]]
#
#  [[228 287]]
#
#  [[221 295]]
#
#  [[214 304]]
#
#  [[223 298]]
#
#  [[230 290]]
#
#  [[236 277]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 80 374]]
#
#  [[ 82 386]]
#
#  [[ 96 372]]
#
#  [[104 361]]
#
#  [[108 353]]
#
#  [[113 351]]
#
#  [[116 349]]
#
#  [[110 348]]
#
#  [[105 354]]
#
#  [[ 96 369]]
#
#  [[ 91 370]]]
# 123
# 348
# Processing shapes from first video
# Drawing shape with points: [[[247 240]]
#
#  [[241 235]]
#
#  [[238 253]]
#
#  [[235 270]]
#
#  [[234 284]]
#
#  [[227 296]]
#
#  [[235 291]]
#
#  [[237 273]]
#
#  [[241 256]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 82 366]]
#
#  [[ 80 376]]
#
#  [[ 97 380]]
#
#  [[103 374]]
#
#  [[107 366]]
#
#  [[106 356]]
#
#  [[107 341]]
#
#  [[104 348]]
#
#  [[104 363]]
#
#  [[ 98 374]]
#
#  [[ 89 370]]]
# 124
# 349
# Processing shapes from first video
# Drawing shape with points: [[[249 218]]
#
#  [[243 216]]
#
#  [[240 234]]
#
#  [[240 250]]
#
#  [[234 272]]
#
#  [[235 288]]
#
#  [[236 273]]
#
#  [[244 253]]
#
#  [[245 234]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 79 365]]
#
#  [[ 78 376]]
#
#  [[ 97 378]]
#
#  [[106 378]]
#
#  [[110 371]]
#
#  [[111 359]]
#
#  [[107 353]]
#
#  [[107 364]]
#
#  [[106 370]]
#
#  [[102 373]]
#
#  [[ 96 372]]
#
#  [[ 90 368]]
#
#  [[ 83 363]]]
# 125
# 350
# Processing shapes from first video
# Drawing shape with points: [[[249 212]]
#
#  [[243 210]]
#
#  [[242 231]]
#
#  [[240 244]]
#
#  [[239 265]]
#
#  [[238 280]]
#
#  [[241 268]]
#
#  [[244 247]]
#
#  [[245 228]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 73 371]]
#
#  [[ 77 383]]
#
#  [[ 88 372]]
#
#  [[ 95 370]]
#
#  [[102 375]]
#
#  [[111 383]]
#
#  [[113 378]]
#
#  [[103 370]]
#
#  [[ 92 364]]
#
#  [[ 85 366]]]
# 126
# 351
# Processing shapes from first video
# Drawing shape with points: [[[249 212]]
#
#  [[243 208]]
#
#  [[243 228]]
#
#  [[241 242]]
#
#  [[240 262]]
#
#  [[239 278]]
#
#  [[241 265]]
#
#  [[244 245]]
#
#  [[246 226]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 73 365]]
#
#  [[ 73 378]]
#
#  [[ 88 374]]
#
#  [[ 95 369]]
#
#  [[102 366]]
#
#  [[109 376]]
#
#  [[107 367]]
#
#  [[102 361]]
#
#  [[ 91 367]]
#
#  [[ 83 369]]]
# 127
# 352
# Processing shapes from first video
# Drawing shape with points: [[[249 209]]
#
#  [[243 208]]
#
#  [[243 228]]
#
#  [[241 242]]
#
#  [[240 262]]
#
#  [[239 278]]
#
#  [[241 265]]
#
#  [[244 245]]
#
#  [[246 226]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 72 359]]
#
#  [[ 70 369]]
#
#  [[ 82 375]]
#
#  [[ 90 380]]
#
#  [[ 96 377]]
#
#  [[102 368]]
#
#  [[107 361]]
#
#  [[101 365]]
#
#  [[ 93 372]]
#
#  [[ 85 372]]]
# 128
# 353
# Processing shapes from first video
# Drawing shape with points: [[[249 209]]
#
#  [[243 208]]
#
#  [[243 228]]
#
#  [[241 242]]
#
#  [[240 262]]
#
#  [[239 278]]
#
#  [[241 265]]
#
#  [[244 245]]
#
#  [[246 226]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 70 356]]
#
#  [[ 68 369]]
#
#  [[ 82 372]]
#
#  [[ 90 379]]
#
#  [[ 96 380]]
#
#  [[100 378]]
#
#  [[104 367]]
#
#  [[ 99 375]]
#
#  [[ 92 377]]
#
#  [[ 84 369]]]
# 129
# 354
# Processing shapes from first video
# Drawing shape with points: [[[249 209]]
#
#  [[243 208]]
#
#  [[243 228]]
#
#  [[241 242]]
#
#  [[240 262]]
#
#  [[239 278]]
#
#  [[241 265]]
#
#  [[244 245]]
#
#  [[246 226]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 66 359]]
#
#  [[ 65 370]]
#
#  [[ 77 369]]
#
#  [[ 85 372]]
#
#  [[ 95 381]]
#
#  [[101 383]]
#
#  [[104 378]]
#
#  [[ 97 378]]
#
#  [[ 88 370]]
#
#  [[ 77 364]]]
# 130
# 355
# Processing shapes from first video
# Drawing shape with points: [[[250 209]]
#
#  [[243 208]]
#
#  [[243 228]]
#
#  [[241 242]]
#
#  [[240 262]]
#
#  [[239 278]]
#
#  [[242 265]]
#
#  [[244 245]]
#
#  [[246 226]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 65 356]]
#
#  [[ 63 366]]
#
#  [[ 75 371]]
#
#  [[ 89 370]]
#
#  [[ 95 374]]
#
#  [[100 388]]
#
#  [[ 97 373]]
#
#  [[ 92 367]]
#
#  [[ 82 365]]
#
#  [[ 73 365]]]
# 131
# 356
# Processing shapes from first video
# Drawing shape with points: [[[250 209]]
#
#  [[243 207]]
#
#  [[243 228]]
#
#  [[241 242]]
#
#  [[240 262]]
#
#  [[239 278]]
#
#  [[242 265]]
#
#  [[244 245]]
#
#  [[246 226]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 65 349]]
#
#  [[ 61 356]]
#
#  [[ 69 366]]
#
#  [[ 78 377]]
#
#  [[ 85 376]]
#
#  [[ 93 370]]
#
#  [[ 98 367]]
#
#  [[ 92 366]]
#
#  [[ 86 372]]
#
#  [[ 80 372]]
#
#  [[ 74 367]]
#
#  [[ 71 361]]]
# 132
# 357
# Processing shapes from first video
# Drawing shape with points: [[[250 209]]
#
#  [[243 207]]
#
#  [[243 228]]
#
#  [[241 242]]
#
#  [[239 264]]
#
#  [[239 278]]
#
#  [[241 264]]
#
#  [[243 246]]
#
#  [[246 226]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 63 346]]
#
#  [[ 59 356]]
#
#  [[ 70 365]]
#
#  [[ 77 378]]
#
#  [[ 83 383]]
#
#  [[ 89 383]]
#
#  [[ 93 377]]
#
#  [[ 93 367]]
#
#  [[ 88 376]]
#
#  [[ 81 377]]
#
#  [[ 73 359]]]
# 133
# 358
# Processing shapes from first video
# Drawing shape with points: [[[250 210]]
#
#  [[242 206]]
#
#  [[243 227]]
#
#  [[241 241]]
#
#  [[238 263]]
#
#  [[238 277]]
#
#  [[240 263]]
#
#  [[242 245]]
#
#  [[246 225]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 58 348]]
#
#  [[ 57 361]]
#
#  [[ 71 360]]
#
#  [[ 78 369]]
#
#  [[ 81 383]]
#
#  [[ 86 389]]
#
#  [[ 85 383]]
#
#  [[ 83 378]]
#
#  [[ 80 367]]
#
#  [[ 77 358]]
#
#  [[ 70 353]]]
# 134
# 359
# Processing shapes from first video
# Drawing shape with points: [[[251 212]]
#
#  [[243 207]]
#
#  [[243 229]]
#
#  [[241 242]]
#
#  [[239 264]]
#
#  [[238 278]]
#
#  [[241 264]]
#
#  [[243 246]]
#
#  [[246 226]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 57 342]]
#
#  [[ 53 352]]
#
#  [[ 65 359]]
#
#  [[ 71 361]]
#
#  [[ 77 364]]
#
#  [[ 81 367]]
#
#  [[ 85 377]]
#
#  [[ 85 369]]
#
#  [[ 83 362]]
#
#  [[ 74 356]]
#
#  [[ 67 353]]]
# 135
# 360
# Processing shapes from first video
# Drawing shape with points: [[[251 212]]
#
#  [[243 207]]
#
#  [[243 229]]
#
#  [[241 242]]
#
#  [[239 264]]
#
#  [[238 278]]
#
#  [[241 264]]
#
#  [[243 246]]
#
#  [[246 226]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 58 331]]
#
#  [[ 52 339]]
#
#  [[ 61 356]]
#
#  [[ 68 366]]
#
#  [[ 75 368]]
#
#  [[ 87 364]]
#
#  [[ 80 361]]
#
#  [[ 74 363]]
#
#  [[ 68 361]]
#
#  [[ 64 354]]
#
#  [[ 61 344]]]
# 136
# 361
# Processing shapes from first video
# Drawing shape with points: [[[250 208]]
#
#  [[243 209]]
#
#  [[243 230]]
#
#  [[241 243]]
#
#  [[239 265]]
#
#  [[238 279]]
#
#  [[241 265]]
#
#  [[243 248]]
#
#  [[246 227]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 54 326]]
#
#  [[ 49 336]]
#
#  [[ 59 344]]
#
#  [[ 63 356]]
#
#  [[ 68 370]]
#
#  [[ 72 374]]
#
#  [[ 78 375]]
#
#  [[ 83 366]]
#
#  [[ 77 370]]
#
#  [[ 73 369]]
#
#  [[ 69 365]]]
# 137
# 362
# Processing shapes from first video
# Drawing shape with points: [[[214 178]]
#
#  [[210 190]]
#
#  [[227 204]]
#
#  [[233 206]]
#
#  [[236 206]]
#
#  [[246 208]]
#
#  [[240 206]]
#
#  [[231 197]]
#
#  [[224 194]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 49 323]]
#
#  [[ 46 337]]
#
#  [[ 54 341]]
#
#  [[ 63 348]]
#
#  [[ 66 358]]
#
#  [[ 69 367]]
#
#  [[ 72 379]]
#
#  [[ 68 354]]
#
#  [[ 61 341]]]
# 138
# 363
# Processing shapes from first video
# Drawing shape with points: [[[187 155]]
#
#  [[183 168]]
#
#  [[195 172]]
#
#  [[204 177]]
#
#  [[213 180]]
#
#  [[219 188]]
#
#  [[215 176]]
#
#  [[205 173]]
#
#  [[197 168]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 48 320]]
#
#  [[ 44 333]]
#
#  [[ 52 339]]
#
#  [[ 60 348]]
#
#  [[ 68 355]]
#
#  [[ 71 380]]
#
#  [[ 73 362]]
#
#  [[ 70 350]]
#
#  [[ 58 339]]]
# 139
# 364
# Processing shapes from first video
# Drawing shape with points: [[[177 148]]
#
#  [[173 160]]
#
#  [[185 165]]
#
#  [[194 170]]
#
#  [[203 173]]
#
#  [[213 180]]
#
#  [[205 171]]
#
#  [[195 166]]
#
#  [[187 160]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 42 323]]
#
#  [[ 47 315]]
#
#  [[ 54 334]]
#
#  [[ 59 344]]
#
#  [[ 65 348]]
#
#  [[ 74 354]]
#
#  [[ 76 363]]
#
#  [[ 69 356]]
#
#  [[ 58 352]]
#
#  [[ 51 339]]]
# 140
# 365
# Processing shapes from first video
# Drawing shape with points: [[[172 144]]
#
#  [[168 157]]
#
#  [[180 161]]
#
#  [[189 166]]
#
#  [[199 169]]
#
#  [[207 176]]
#
#  [[200 167]]
#
#  [[190 162]]
#
#  [[182 157]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 38 319]]
#
#  [[ 44 308]]
#
#  [[ 50 323]]
#
#  [[ 57 334]]
#
#  [[ 61 344]]
#
#  [[ 64 358]]
#
#  [[ 69 366]]
#
#  [[ 61 363]]
#
#  [[ 57 342]]
#
#  [[ 49 332]]]
# 141
# 366
# Processing shapes from first video
# Drawing shape with points: [[[169 143]]
#
#  [[166 155]]
#
#  [[178 160]]
#
#  [[187 165]]
#
#  [[196 168]]
#
#  [[206 173]]
#
#  [[198 165]]
#
#  [[188 160]]
#
#  [[180 155]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 37 317]]
#
#  [[ 42 306]]
#
#  [[ 48 322]]
#
#  [[ 55 333]]
#
#  [[ 61 340]]
#
#  [[ 64 348]]
#
#  [[ 64 369]]
#
#  [[ 59 345]]
#
#  [[ 55 340]]
#
#  [[ 48 330]]]
# 142
# 367
# Processing shapes from first video
# Drawing shape with points: [[[166 143]]
#
#  [[163 155]]
#
#  [[176 160]]
#
#  [[184 165]]
#
#  [[194 168]]
#
#  [[203 170]]
#
#  [[196 165]]
#
#  [[185 160]]
#
#  [[178 155]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 36 315]]
#
#  [[ 41 304]]
#
#  [[ 47 319]]
#
#  [[ 53 330]]
#
#  [[ 60 337]]
#
#  [[ 66 350]]
#
#  [[ 64 364]]
#
#  [[ 62 348]]
#
#  [[ 54 337]]
#
#  [[ 47 328]]]
# 143
# 368
# Processing shapes from first video
# Drawing shape with points: [[[164 142]]
#
#  [[161 154]]
#
#  [[174 157]]
#
#  [[183 162]]
#
#  [[192 167]]
#
#  [[201 169]]
#
#  [[194 165]]
#
#  [[184 158]]
#
#  [[178 154]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 34 311]]
#
#  [[ 39 300]]
#
#  [[ 45 315]]
#
#  [[ 51 326]]
#
#  [[ 55 334]]
#
#  [[ 64 346]]
#
#  [[ 68 356]]
#
#  [[ 58 346]]
#
#  [[ 51 336]]
#
#  [[ 45 324]]]
# 144
# 369
# Processing shapes from first video
# Drawing shape with points: [[[163 141]]
#
#  [[160 154]]
#
#  [[172 156]]
#
#  [[181 161]]
#
#  [[190 166]]
#
#  [[200 169]]
#
#  [[192 164]]
#
#  [[182 157]]
#
#  [[176 153]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 39 300]]
#
#  [[ 35 309]]
#
#  [[ 48 327]]
#
#  [[ 60 354]]
#
#  [[ 67 355]]
#
#  [[ 60 344]]
#
#  [[ 51 326]]]
# 145
# 370
# Processing shapes from first video
# Drawing shape with points: [[[162 141]]
#
#  [[159 153]]
#
#  [[171 155]]
#
#  [[180 161]]
#
#  [[189 166]]
#
#  [[199 168]]
#
#  [[191 163]]
#
#  [[181 157]]
#
#  [[175 152]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 38 299]]
#
#  [[ 34 308]]
#
#  [[ 47 326]]
#
#  [[ 58 350]]
#
#  [[ 68 356]]
#
#  [[ 59 345]]
#
#  [[ 50 325]]]
# 146
# 371
# Processing shapes from first video
# Drawing shape with points: [[[161 139]]
#
#  [[158 152]]
#
#  [[170 154]]
#
#  [[179 160]]
#
#  [[188 165]]
#
#  [[198 167]]
#
#  [[190 162]]
#
#  [[180 155]]
#
#  [[174 151]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 37 298]]
#
#  [[ 33 307]]
#
#  [[ 47 325]]
#
#  [[ 57 349]]
#
#  [[ 67 355]]
#
#  [[ 59 344]]
#
#  [[ 50 323]]]
# 147
# 372
# Processing shapes from first video
# Drawing shape with points: [[[158 138]]
#
#  [[155 150]]
#
#  [[168 153]]
#
#  [[177 158]]
#
#  [[186 163]]
#
#  [[195 166]]
#
#  [[188 161]]
#
#  [[178 154]]
#
#  [[172 150]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 37 298]]
#
#  [[ 33 307]]
#
#  [[ 47 325]]
#
#  [[ 57 349]]
#
#  [[ 67 355]]
#
#  [[ 59 344]]
#
#  [[ 50 323]]]
# 148
# 373
# Processing shapes from first video
# Drawing shape with points: [[[157 139]]
#
#  [[156 153]]
#
#  [[168 153]]
#
#  [[177 158]]
#
#  [[186 163]]
#
#  [[195 166]]
#
#  [[188 161]]
#
#  [[178 154]]
#
#  [[172 150]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 37 295]]
#
#  [[ 32 305]]
#
#  [[ 46 323]]
#
#  [[ 57 348]]
#
#  [[ 63 356]]
#
#  [[ 58 342]]
#
#  [[ 49 322]]]
# 149
# 374
# Processing shapes from first video
# Drawing shape with points: [[[157 139]]
#
#  [[156 153]]
#
#  [[168 153]]
#
#  [[177 158]]
#
#  [[186 163]]
#
#  [[195 166]]
#
#  [[188 161]]
#
#  [[178 154]]
#
#  [[170 149]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 37 294]]
#
#  [[ 32 304]]
#
#  [[ 43 319]]
#
#  [[ 55 345]]
#
#  [[ 62 355]]
#
#  [[ 58 341]]
#
#  [[ 47 317]]]
# 150
# 375
# Processing shapes from first video
# Drawing shape with points: [[[157 139]]
#
#  [[155 153]]
#
#  [[167 153]]
#
#  [[176 158]]
#
#  [[185 163]]
#
#  [[194 166]]
#
#  [[187 161]]
#
#  [[177 154]]
#
#  [[169 149]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 36 292]]
#
#  [[ 31 302]]
#
#  [[ 42 317]]
#
#  [[ 54 344]]
#
#  [[ 61 353]]
#
#  [[ 57 339]]
#
#  [[ 46 315]]]
# 151
# 376
# Processing shapes from first video
# Drawing shape with points: [[[156 139]]
#
#  [[155 152]]
#
#  [[166 152]]
#
#  [[176 158]]
#
#  [[184 163]]
#
#  [[194 165]]
#
#  [[186 160]]
#
#  [[177 154]]
#
#  [[168 149]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 36 292]]
#
#  [[ 31 302]]
#
#  [[ 42 317]]
#
#  [[ 54 344]]
#
#  [[ 61 353]]
#
#  [[ 57 339]]
#
#  [[ 46 315]]]
# 152
# 377
# Processing shapes from first video
# Drawing shape with points: [[[155 138]]
#
#  [[154 152]]
#
#  [[165 152]]
#
#  [[175 157]]
#
#  [[184 162]]
#
#  [[193 165]]
#
#  [[185 160]]
#
#  [[176 153]]
#
#  [[168 148]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 36 292]]
#
#  [[ 31 302]]
#
#  [[ 42 317]]
#
#  [[ 54 344]]
#
#  [[ 61 353]]
#
#  [[ 57 339]]
#
#  [[ 46 315]]]
# 153
# 378
# Processing shapes from first video
# Drawing shape with points: [[[154 137]]
#
#  [[153 150]]
#
#  [[164 151]]
#
#  [[174 156]]
#
#  [[183 161]]
#
#  [[192 163]]
#
#  [[184 158]]
#
#  [[175 152]]
#
#  [[167 147]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 36 291]]
#
#  [[ 31 301]]
#
#  [[ 42 315]]
#
#  [[ 53 341]]
#
#  [[ 59 353]]
#
#  [[ 54 336]]
#
#  [[ 46 314]]]
# 154
# 379
# Processing shapes from first video
# Drawing shape with points: [[[154 137]]
#
#  [[153 150]]
#
#  [[164 151]]
#
#  [[174 156]]
#
#  [[183 161]]
#
#  [[192 163]]
#
#  [[184 158]]
#
#  [[175 152]]
#
#  [[167 147]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 36 291]]
#
#  [[ 31 301]]
#
#  [[ 42 315]]
#
#  [[ 53 341]]
#
#  [[ 59 353]]
#
#  [[ 54 336]]
#
#  [[ 46 314]]]
# 155
# 380
# Processing shapes from first video
# Drawing shape with points: [[[154 137]]
#
#  [[152 150]]
#
#  [[163 151]]
#
#  [[173 156]]
#
#  [[182 161]]
#
#  [[192 163]]
#
#  [[184 158]]
#
#  [[174 152]]
#
#  [[166 147]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 36 290]]
#
#  [[ 30 300]]
#
#  [[ 40 315]]
#
#  [[ 52 340]]
#
#  [[ 58 352]]
#
#  [[ 54 334]]
#
#  [[ 45 312]]]
# 156
# 381
# Processing shapes from first video
# Drawing shape with points: [[[153 137]]
#
#  [[152 150]]
#
#  [[163 151]]
#
#  [[173 156]]
#
#  [[182 161]]
#
#  [[191 163]]
#
#  [[183 158]]
#
#  [[174 152]]
#
#  [[166 147]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 36 290]]
#
#  [[ 30 300]]
#
#  [[ 40 315]]
#
#  [[ 52 340]]
#
#  [[ 58 352]]
#
#  [[ 54 334]]
#
#  [[ 45 312]]]
# 157
# 382
# Processing shapes from first video
# Drawing shape with points: [[[153 137]]
#
#  [[152 150]]
#
#  [[162 150]]
#
#  [[173 156]]
#
#  [[182 161]]
#
#  [[191 163]]
#
#  [[183 158]]
#
#  [[174 152]]
#
#  [[166 147]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 287]]
#
#  [[ 29 297]]
#
#  [[ 39 312]]
#
#  [[ 51 337]]
#
#  [[ 57 349]]
#
#  [[ 53 332]]
#
#  [[ 44 310]]]
# 158
# 383
# Processing shapes from first video
# Drawing shape with points: [[[153 137]]
#
#  [[152 150]]
#
#  [[162 150]]
#
#  [[173 156]]
#
#  [[182 161]]
#
#  [[191 163]]
#
#  [[183 158]]
#
#  [[174 152]]
#
#  [[166 147]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 287]]
#
#  [[ 29 297]]
#
#  [[ 39 312]]
#
#  [[ 51 337]]
#
#  [[ 57 349]]
#
#  [[ 53 332]]
#
#  [[ 44 310]]]
# 159
# 384
# Processing shapes from first video
# Drawing shape with points: [[[152 137]]
#
#  [[151 150]]
#
#  [[161 150]]
#
#  [[172 156]]
#
#  [[181 161]]
#
#  [[190 163]]
#
#  [[182 158]]
#
#  [[173 152]]
#
#  [[165 147]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 287]]
#
#  [[ 29 297]]
#
#  [[ 39 312]]
#
#  [[ 51 337]]
#
#  [[ 57 349]]
#
#  [[ 51 330]]
#
#  [[ 44 310]]]
# 160
# 385
# Processing shapes from first video
# Drawing shape with points: [[[152 137]]
#
#  [[151 150]]
#
#  [[161 150]]
#
#  [[172 156]]
#
#  [[181 161]]
#
#  [[190 163]]
#
#  [[182 158]]
#
#  [[173 152]]
#
#  [[165 147]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 36 286]]
#
#  [[ 30 294]]
#
#  [[ 39 312]]
#
#  [[ 51 337]]
#
#  [[ 57 349]]
#
#  [[ 51 330]]
#
#  [[ 44 310]]]
# 161
# 386
# Processing shapes from first video
# Drawing shape with points: [[[152 137]]
#
#  [[151 150]]
#
#  [[161 150]]
#
#  [[172 156]]
#
#  [[181 161]]
#
#  [[190 163]]
#
#  [[182 158]]
#
#  [[173 152]]
#
#  [[165 147]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 36 286]]
#
#  [[ 30 294]]
#
#  [[ 39 312]]
#
#  [[ 51 337]]
#
#  [[ 57 349]]
#
#  [[ 51 330]]
#
#  [[ 44 310]]]
# 162
# 387
# Processing shapes from first video
# Drawing shape with points: [[[152 137]]
#
#  [[151 150]]
#
#  [[161 150]]
#
#  [[172 156]]
#
#  [[181 161]]
#
#  [[190 163]]
#
#  [[182 158]]
#
#  [[173 152]]
#
#  [[165 147]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 36 286]]
#
#  [[ 30 294]]
#
#  [[ 39 312]]
#
#  [[ 51 337]]
#
#  [[ 57 349]]
#
#  [[ 51 330]]
#
#  [[ 44 310]]]
# 163
# 388
# Processing shapes from first video
# Drawing shape with points: [[[151 136]]
#
#  [[150 150]]
#
#  [[161 150]]
#
#  [[172 156]]
#
#  [[181 161]]
#
#  [[190 163]]
#
#  [[182 158]]
#
#  [[173 152]]
#
#  [[162 147]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 36 286]]
#
#  [[ 30 294]]
#
#  [[ 38 308]]
#
#  [[ 47 330]]
#
#  [[ 57 349]]
#
#  [[ 51 330]]
#
#  [[ 42 306]]]
# 164
# 389
# Processing shapes from first video
# Drawing shape with points: [[[154 134]]
#
#  [[149 147]]
#
#  [[161 155]]
#
#  [[171 158]]
#
#  [[180 156]]
#
#  [[189 158]]
#
#  [[179 154]]
#
#  [[169 154]]
#
#  [[162 147]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 36 286]]
#
#  [[ 30 294]]
#
#  [[ 38 308]]
#
#  [[ 47 330]]
#
#  [[ 57 349]]
#
#  [[ 51 330]]
#
#  [[ 42 306]]]
# 165
# 390
# Processing shapes from first video
# Drawing shape with points: [[[149 114]]
#
#  [[145 123]]
#
#  [[151 134]]
#
#  [[156 141]]
#
#  [[162 166]]
#
#  [[172 167]]
#
#  [[163 160]]
#
#  [[157 140]]
#
#  [[155 127]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 284]]
#
#  [[ 29 292]]
#
#  [[ 38 306]]
#
#  [[ 47 328]]
#
#  [[ 57 347]]
#
#  [[ 50 328]]
#
#  [[ 41 304]]]
# 166
# 391
# Processing shapes from first video
# Drawing shape with points: [[[139  92]]
#
#  [[135 100]]
#
#  [[141 111]]
#
#  [[146 123]]
#
#  [[153 136]]
#
#  [[162 144]]
#
#  [[156 136]]
#
#  [[149 124]]
#
#  [[144 108]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 284]]
#
#  [[ 29 292]]
#
#  [[ 38 306]]
#
#  [[ 47 328]]
#
#  [[ 57 347]]
#
#  [[ 50 328]]
#
#  [[ 41 304]]]
# 167
# 392
# Processing shapes from first video
# Drawing shape with points: [[[134  80]]
#
#  [[129  89]]
#
#  [[136 100]]
#
#  [[141 111]]
#
#  [[148 125]]
#
#  [[156 143]]
#
#  [[151 124]]
#
#  [[144 112]]
#
#  [[139  96]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 284]]
#
#  [[ 29 292]]
#
#  [[ 38 306]]
#
#  [[ 47 328]]
#
#  [[ 57 347]]
#
#  [[ 50 328]]
#
#  [[ 41 304]]]
# 168
# 393
# Processing shapes from first video
# Drawing shape with points: [[[132  74]]
#
#  [[127  83]]
#
#  [[134  94]]
#
#  [[139 105]]
#
#  [[146 119]]
#
#  [[154 137]]
#
#  [[148 120]]
#
#  [[141 106]]
#
#  [[137  90]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 284]]
#
#  [[ 29 292]]
#
#  [[ 38 306]]
#
#  [[ 47 328]]
#
#  [[ 57 347]]
#
#  [[ 50 328]]
#
#  [[ 41 304]]]
# 169
# 394
# Processing shapes from first video
# Drawing shape with points: [[[132  74]]
#
#  [[127  83]]
#
#  [[134  94]]
#
#  [[139 105]]
#
#  [[146 119]]
#
#  [[154 137]]
#
#  [[148 120]]
#
#  [[141 106]]
#
#  [[137  90]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 284]]
#
#  [[ 29 292]]
#
#  [[ 38 306]]
#
#  [[ 47 328]]
#
#  [[ 57 347]]
#
#  [[ 50 328]]
#
#  [[ 41 304]]]
# 170
# 395
# Processing shapes from first video
# Drawing shape with points: [[[131  67]]
#
#  [[126  76]]
#
#  [[133  87]]
#
#  [[138  99]]
#
#  [[143 114]]
#
#  [[151 134]]
#
#  [[144 113]]
#
#  [[140  99]]
#
#  [[136  83]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 284]]
#
#  [[ 29 292]]
#
#  [[ 38 306]]
#
#  [[ 47 328]]
#
#  [[ 57 347]]
#
#  [[ 50 328]]
#
#  [[ 41 304]]]
# 171
# 396
# Processing shapes from first video
# Drawing shape with points: [[[131  65]]
#
#  [[125  70]]
#
#  [[133  84]]
#
#  [[138  96]]
#
#  [[143 112]]
#
#  [[151 132]]
#
#  [[144 111]]
#
#  [[140  97]]
#
#  [[136  81]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 284]]
#
#  [[ 29 292]]
#
#  [[ 38 306]]
#
#  [[ 47 328]]
#
#  [[ 57 347]]
#
#  [[ 50 328]]
#
#  [[ 41 304]]]
# 172
# 397
# Processing shapes from first video
# Drawing shape with points: [[[107  54]]
#
#  [[102  65]]
#
#  [[112  70]]
#
#  [[117  80]]
#
#  [[128  84]]
#
#  [[139  75]]
#
#  [[127  79]]
#
#  [[119  77]]
#
#  [[112  67]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 284]]
#
#  [[ 29 292]]
#
#  [[ 38 306]]
#
#  [[ 47 328]]
#
#  [[ 57 347]]
#
#  [[ 50 328]]
#
#  [[ 41 304]]]
# 173
# 398
# Processing shapes from first video
# Drawing shape with points: [[[ 87  48]]
#
#  [[ 85  61]]
#
#  [[ 96  61]]
#
#  [[109  65]]
#
#  [[117  67]]
#
#  [[123  75]]
#
#  [[118  62]]
#
#  [[105  59]]
#
#  [[ 99  57]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 282]]
#
#  [[ 29 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 56 345]]
#
#  [[ 50 326]]
#
#  [[ 41 302]]]
# 174
# 399
# Processing shapes from first video
# Drawing shape with points: [[[ 85  51]]
#
#  [[ 84  64]]
#
#  [[ 94  64]]
#
#  [[107  68]]
#
#  [[115  70]]
#
#  [[124  70]]
#
#  [[116  66]]
#
#  [[104  62]]
#
#  [[ 97  60]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 282]]
#
#  [[ 29 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 56 345]]
#
#  [[ 50 326]]
#
#  [[ 41 302]]]
# 175
# 400
# Processing shapes from first video
# Drawing shape with points: [[[ 85  51]]
#
#  [[ 84  64]]
#
#  [[ 94  64]]
#
#  [[107  68]]
#
#  [[115  70]]
#
#  [[124  70]]
#
#  [[116  66]]
#
#  [[104  62]]
#
#  [[ 97  60]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 282]]
#
#  [[ 29 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 56 345]]
#
#  [[ 50 326]]
#
#  [[ 41 302]]]
# 176
# 401
# Processing shapes from first video
# Drawing shape with points: [[[ 84  51]]
#
#  [[ 82  64]]
#
#  [[ 93  64]]
#
#  [[106  68]]
#
#  [[114  70]]
#
#  [[123  70]]
#
#  [[115  66]]
#
#  [[102  62]]
#
#  [[ 95  60]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 282]]
#
#  [[ 29 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 56 345]]
#
#  [[ 50 326]]
#
#  [[ 41 302]]]
# 177
# 402
# Processing shapes from first video
# Drawing shape with points: [[[ 84  51]]
#
#  [[ 82  64]]
#
#  [[ 93  64]]
#
#  [[106  68]]
#
#  [[114  70]]
#
#  [[123  70]]
#
#  [[115  66]]
#
#  [[102  62]]
#
#  [[ 95  60]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 282]]
#
#  [[ 29 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 56 345]]
#
#  [[ 50 326]]
#
#  [[ 41 302]]]
# 178
# 403
# Processing shapes from first video
# Drawing shape with points: [[[ 84  53]]
#
#  [[ 82  66]]
#
#  [[ 93  66]]
#
#  [[106  69]]
#
#  [[114  71]]
#
#  [[125  69]]
#
#  [[115  67]]
#
#  [[102  64]]
#
#  [[ 95  61]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 282]]
#
#  [[ 29 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 56 345]]
#
#  [[ 50 326]]
#
#  [[ 41 302]]]
# 179
# 404
# Processing shapes from first video
# Drawing shape with points: [[[ 84  53]]
#
#  [[ 82  66]]
#
#  [[ 93  66]]
#
#  [[107  67]]
#
#  [[114  68]]
#
#  [[125  69]]
#
#  [[116  66]]
#
#  [[103  62]]
#
#  [[ 95  61]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 282]]
#
#  [[ 29 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 56 345]]
#
#  [[ 50 326]]
#
#  [[ 41 302]]]
# 180
# 405
# Processing shapes from first video
# Drawing shape with points: [[[ 84  53]]
#
#  [[ 82  66]]
#
#  [[ 93  66]]
#
#  [[107  67]]
#
#  [[114  68]]
#
#  [[125  69]]
#
#  [[116  66]]
#
#  [[103  62]]
#
#  [[ 95  61]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 282]]
#
#  [[ 29 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 56 345]]
#
#  [[ 50 326]]
#
#  [[ 41 302]]]
# 181
# 406
# Processing shapes from first video
# Drawing shape with points: [[[ 84  53]]
#
#  [[ 82  66]]
#
#  [[ 93  66]]
#
#  [[107  67]]
#
#  [[114  68]]
#
#  [[125  69]]
#
#  [[116  66]]
#
#  [[103  62]]
#
#  [[ 95  61]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 282]]
#
#  [[ 29 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 56 345]]
#
#  [[ 50 326]]
#
#  [[ 41 302]]]
# 182
# 407
# Processing shapes from first video
# Drawing shape with points: [[[ 84  53]]
#
#  [[ 82  66]]
#
#  [[ 93  66]]
#
#  [[107  67]]
#
#  [[114  68]]
#
#  [[125  69]]
#
#  [[116  66]]
#
#  [[103  62]]
#
#  [[ 95  61]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 282]]
#
#  [[ 29 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 56 345]]
#
#  [[ 50 326]]
#
#  [[ 41 302]]]
# 183
# 408
# Processing shapes from first video
# Drawing shape with points: [[[ 84  53]]
#
#  [[ 82  66]]
#
#  [[ 93  66]]
#
#  [[107  67]]
#
#  [[114  68]]
#
#  [[125  69]]
#
#  [[116  66]]
#
#  [[103  62]]
#
#  [[ 95  61]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 35 282]]
#
#  [[ 29 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 56 345]]
#
#  [[ 50 326]]
#
#  [[ 41 302]]]
# 184
# 409
# Processing shapes from first video
# Drawing shape with points: [[[ 84  53]]
#
#  [[ 82  66]]
#
#  [[ 93  66]]
#
#  [[107  67]]
#
#  [[114  68]]
#
#  [[125  69]]
#
#  [[116  66]]
#
#  [[103  62]]
#
#  [[ 95  61]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 34 282]]
#
#  [[ 28 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 55 346]]
#
#  [[ 49 325]]
#
#  [[ 40 301]]]
# 185
# 410
# Processing shapes from first video
# Drawing shape with points: [[[ 90  49]]
#
#  [[ 85  59]]
#
#  [[ 94  70]]
#
#  [[101  79]]
#
#  [[111  73]]
#
#  [[118  55]]
#
#  [[111  67]]
#
#  [[103  73]]
#
#  [[ 97  67]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 34 282]]
#
#  [[ 28 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 55 346]]
#
#  [[ 49 325]]
#
#  [[ 40 301]]]
# 186
# 411
# Processing shapes from first video
# Drawing shape with points: [[[ 83  55]]
#
#  [[ 81  67]]
#
#  [[ 94  71]]
#
#  [[100  75]]
#
#  [[108  86]]
#
#  [[116  86]]
#
#  [[109  81]]
#
#  [[101  71]]
#
#  [[ 95  66]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 34 282]]
#
#  [[ 28 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 54 348]]
#
#  [[ 49 325]]
#
#  [[ 40 301]]]
# 187
# 412
# Processing shapes from first video
# Drawing shape with points: [[[ 82  56]]
#
#  [[ 79  69]]
#
#  [[ 91  75]]
#
#  [[ 97  78]]
#
#  [[107  84]]
#
#  [[119  89]]
#
#  [[108  81]]
#
#  [[100  74]]
#
#  [[ 93  70]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 34 282]]
#
#  [[ 28 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 54 348]]
#
#  [[ 49 325]]
#
#  [[ 40 301]]]
# 188
# 413
# Processing shapes from first video
# Drawing shape with points: [[[ 82  56]]
#
#  [[ 79  69]]
#
#  [[ 91  75]]
#
#  [[ 97  78]]
#
#  [[107  84]]
#
#  [[119  89]]
#
#  [[108  81]]
#
#  [[100  74]]
#
#  [[ 93  70]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 34 282]]
#
#  [[ 28 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 54 348]]
#
#  [[ 49 325]]
#
#  [[ 40 301]]]
# 189
# 414
# Processing shapes from first video
# Drawing shape with points: [[[ 82  56]]
#
#  [[ 79  69]]
#
#  [[ 91  75]]
#
#  [[ 97  78]]
#
#  [[107  84]]
#
#  [[118  92]]
#
#  [[108  81]]
#
#  [[100  74]]
#
#  [[ 93  70]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 34 282]]
#
#  [[ 28 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 54 348]]
#
#  [[ 49 325]]
#
#  [[ 40 301]]]
# 190
# 415
# Processing shapes from first video
# Drawing shape with points: [[[ 82  56]]
#
#  [[ 79  69]]
#
#  [[ 91  75]]
#
#  [[ 97  78]]
#
#  [[107  84]]
#
#  [[118  92]]
#
#  [[108  81]]
#
#  [[100  74]]
#
#  [[ 93  70]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 34 282]]
#
#  [[ 28 290]]
#
#  [[ 37 304]]
#
#  [[ 46 326]]
#
#  [[ 54 348]]
#
#  [[ 49 325]]
#
#  [[ 40 301]]]
# 191
# 416
# Processing shapes from first video
# Drawing shape with points: [[[ 82  77]]
#
#  [[ 85  86]]
#
#  [[ 91  75]]
#
#  [[101  67]]
#
#  [[108  73]]
#
#  [[110  97]]
#
#  [[109  69]]
#
#  [[100  62]]
#
#  [[ 93  66]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 34 281]]
#
#  [[ 28 289]]
#
#  [[ 37 303]]
#
#  [[ 46 325]]
#
#  [[ 54 347]]
#
#  [[ 49 322]]
#
#  [[ 40 300]]]
# 192
# 417
# Processing shapes from first video
# Drawing shape with points: [[[ 68  79]]
#
#  [[ 68  91]]
#
#  [[ 78  82]]
#
#  [[ 86  81]]
#
#  [[ 93  80]]
#
#  [[103  64]]
#
#  [[ 94  75]]
#
#  [[ 87  78]]
#
#  [[ 79  77]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 34 281]]
#
#  [[ 28 289]]
#
#  [[ 37 303]]
#
#  [[ 46 325]]
#
#  [[ 54 347]]
#
#  [[ 49 322]]
#
#  [[ 40 300]]]
# 193
# 418
# Processing shapes from first video
# Drawing shape with points: [[[ 62  92]]
#
#  [[ 63 103]]
#
#  [[ 72  95]]
#
#  [[ 80  87]]
#
#  [[ 89  75]]
#
#  [[ 98  68]]
#
#  [[ 89  72]]
#
#  [[ 81  79]]
#
#  [[ 74  86]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 34 281]]
#
#  [[ 28 289]]
#
#  [[ 37 303]]
#
#  [[ 46 325]]
#
#  [[ 54 347]]
#
#  [[ 48 323]]
#
#  [[ 40 300]]]
# 194
# 419
# Processing shapes from first video
# Drawing shape with points: [[[ 60  92]]
#
#  [[ 63 105]]
#
#  [[ 72  95]]
#
#  [[ 80  87]]
#
#  [[ 89  75]]
#
#  [[ 98  68]]
#
#  [[ 89  72]]
#
#  [[ 81  79]]
#
#  [[ 72  88]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 34 281]]
#
#  [[ 28 289]]
#
#  [[ 37 303]]
#
#  [[ 46 325]]
#
#  [[ 54 347]]
#
#  [[ 48 323]]
#
#  [[ 40 300]]]
# 195
# 420
# Processing shapes from first video
# Drawing shape with points: [[[ 60  92]]
#
#  [[ 63 105]]
#
#  [[ 72  95]]
#
#  [[ 80  87]]
#
#  [[ 89  75]]
#
#  [[ 98  68]]
#
#  [[ 89  72]]
#
#  [[ 84  78]]
#
#  [[ 72  88]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 34 281]]
#
#  [[ 28 289]]
#
#  [[ 37 303]]
#
#  [[ 46 325]]
#
#  [[ 54 347]]
#
#  [[ 48 323]]
#
#  [[ 40 300]]]
# 196
# 421
# Processing shapes from first video
# Drawing shape with points: [[[ 60  92]]
#
#  [[ 63 105]]
#
#  [[ 72  95]]
#
#  [[ 80  87]]
#
#  [[ 89  75]]
#
#  [[ 98  68]]
#
#  [[ 89  72]]
#
#  [[ 84  78]]
#
#  [[ 72  88]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 34 281]]
#
#  [[ 28 289]]
#
#  [[ 37 303]]
#
#  [[ 46 325]]
#
#  [[ 54 347]]
#
#  [[ 48 323]]
#
#  [[ 40 300]]]
# 197
# 422
# Processing shapes from first video
# Drawing shape with points: [[[ 60  92]]
#
#  [[ 63 105]]
#
#  [[ 72  95]]
#
#  [[ 80  87]]
#
#  [[ 89  75]]
#
#  [[ 97  66]]
#
#  [[ 89  72]]
#
#  [[ 84  78]]
#
#  [[ 72  88]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 34 281]]
#
#  [[ 28 289]]
#
#  [[ 37 303]]
#
#  [[ 46 325]]
#
#  [[ 54 347]]
#
#  [[ 48 323]]
#
#  [[ 40 300]]]
# 198
# 423
# Processing shapes from first video
# Drawing shape with points: [[[ 60  92]]
#
#  [[ 63 105]]
#
#  [[ 72  95]]
#
#  [[ 80  87]]
#
#  [[ 89  75]]
#
#  [[ 97  66]]
#
#  [[ 89  72]]
#
#  [[ 84  78]]
#
#  [[ 72  88]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 34 281]]
#
#  [[ 28 289]]
#
#  [[ 37 303]]
#
#  [[ 46 325]]
#
#  [[ 54 347]]
#
#  [[ 48 323]]
#
#  [[ 40 300]]]
# 199
# 424
# Processing shapes from first video
# Drawing shape with points: [[[ 60  95]]
#
#  [[ 63 105]]
#
#  [[ 72  95]]
#
#  [[ 80  87]]
#
#  [[ 89  75]]
#
#  [[ 97  66]]
#
#  [[ 89  72]]
#
#  [[ 84  78]]
#
#  [[ 72  88]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 34 281]]
#
#  [[ 28 289]]
#
#  [[ 37 303]]
#
#  [[ 46 325]]
#
#  [[ 54 347]]
#
#  [[ 48 323]]
#
#  [[ 40 300]]]
# 200
# 425
# Processing shapes from first video
# Drawing shape with points: [[[ 60  95]]
#
#  [[ 63 105]]
#
#  [[ 72  95]]
#
#  [[ 80  87]]
#
#  [[ 89  75]]
#
#  [[ 97  66]]
#
#  [[ 89  72]]
#
#  [[ 84  78]]
#
#  [[ 72  88]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 30 284]]
#
#  [[ 37 279]]
#
#  [[ 39 302]]
#
#  [[ 42 311]]
#
#  [[ 48 322]]
#
#  [[ 53 332]]
#
#  [[ 52 344]]
#
#  [[ 50 334]]
#
#  [[ 49 328]]
#
#  [[ 44 323]]
#
#  [[ 38 312]]
#
#  [[ 35 295]]]
# 201
# 426
# Processing shapes from first video
# Drawing shape with points: [[[ 60  95]]
#
#  [[ 63 105]]
#
#  [[ 72  95]]
#
#  [[ 80  84]]
#
#  [[ 89  75]]
#
#  [[ 97  66]]
#
#  [[ 89  72]]
#
#  [[ 84  78]]
#
#  [[ 72  88]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 31 282]]
#
#  [[ 37 280]]
#
#  [[ 39 300]]
#
#  [[ 39 308]]
#
#  [[ 41 317]]
#
#  [[ 47 323]]
#
#  [[ 52 326]]
#
#  [[ 56 332]]
#
#  [[ 44 328]]
#
#  [[ 40 322]]
#
#  [[ 35 307]]]
# 202
# 427
# Processing shapes from first video
# Drawing shape with points: [[[ 60  95]]
#
#  [[ 63 105]]
#
#  [[ 72  95]]
#
#  [[ 80  84]]
#
#  [[ 89  75]]
#
#  [[ 97  66]]
#
#  [[ 89  72]]
#
#  [[ 84  78]]
#
#  [[ 72  88]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 29 282]]
#
#  [[ 36 276]]
#
#  [[ 39 289]]
#
#  [[ 39 304]]
#
#  [[ 40 317]]
#
#  [[ 43 328]]
#
#  [[ 50 329]]
#
#  [[ 54 328]]
#
#  [[ 45 335]]
#
#  [[ 41 330]]
#
#  [[ 38 323]]
#
#  [[ 38 309]]
#
#  [[ 36 298]]]
# 203
# 428
# Processing shapes from first video
# Drawing shape with points: [[[ 57 102]]
#
#  [[ 59 112]]
#
#  [[ 69 102]]
#
#  [[ 76  90]]
#
#  [[ 83  76]]
#
#  [[ 91  67]]
#
#  [[ 82  70]]
#
#  [[ 76  81]]
#
#  [[ 69  94]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 28 279]]
#
#  [[ 33 273]]
#
#  [[ 37 288]]
#
#  [[ 41 303]]
#
#  [[ 44 320]]
#
#  [[ 44 330]]
#
#  [[ 48 339]]
#
#  [[ 42 334]]
#
#  [[ 41 321]]
#
#  [[ 38 302]]]
# 204
# 429
# Processing shapes from first video
# Drawing shape with points: [[[ 51 123]]
#
#  [[ 55 135]]
#
#  [[ 62 115]]
#
#  [[ 66  98]]
#
#  [[ 74  92]]
#
#  [[ 82  88]]
#
#  [[ 71  90]]
#
#  [[ 65  96]]
#
#  [[ 60 110]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 27 273]]
#
#  [[ 33 268]]
#
#  [[ 34 286]]
#
#  [[ 39 299]]
#
#  [[ 46 311]]
#
#  [[ 48 325]]
#
#  [[ 42 341]]
#
#  [[ 44 323]]
#
#  [[ 41 310]]
#
#  [[ 35 300]]
#
#  [[ 30 289]]]
# 205
# 430
# Processing shapes from first video
# Drawing shape with points: [[[ 46 148]]
#
#  [[ 52 153]]
#
#  [[ 55 130]]
#
#  [[ 60 117]]
#
#  [[ 66 107]]
#
#  [[ 65  92]]
#
#  [[ 63 105]]
#
#  [[ 59 113]]
#
#  [[ 52 128]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 29 267]]
#
#  [[ 36 268]]
#
#  [[ 33 289]]
#
#  [[ 36 300]]
#
#  [[ 41 308]]
#
#  [[ 48 315]]
#
#  [[ 49 326]]
#
#  [[ 43 317]]
#
#  [[ 36 311]]
#
#  [[ 33 304]]
#
#  [[ 30 291]]]
# 206
# 431
# Processing shapes from first video
# Drawing shape with points: [[[ 43 160]]
#
#  [[ 49 165]]
#
#  [[ 53 141]]
#
#  [[ 55 128]]
#
#  [[ 58 116]]
#
#  [[ 62  97]]
#
#  [[ 59 110]]
#
#  [[ 55 122]]
#
#  [[ 49 140]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 29 265]]
#
#  [[ 36 265]]
#
#  [[ 36 284]]
#
#  [[ 35 300]]
#
#  [[ 38 312]]
#
#  [[ 43 314]]
#
#  [[ 49 314]]
#
#  [[ 43 319]]
#
#  [[ 37 317]]
#
#  [[ 34 312]]
#
#  [[ 32 301]]
#
#  [[ 32 289]]]
# 207
# 432
# Processing shapes from first video
# Drawing shape with points: [[[ 43 160]]
#
#  [[ 49 165]]
#
#  [[ 53 141]]
#
#  [[ 55 128]]
#
#  [[ 58 116]]
#
#  [[ 62  97]]
#
#  [[ 59 110]]
#
#  [[ 55 122]]
#
#  [[ 49 140]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 26 262]]
#
#  [[ 33 257]]
#
#  [[ 35 275]]
#
#  [[ 37 290]]
#
#  [[ 37 304]]
#
#  [[ 37 312]]
#
#  [[ 38 319]]
#
#  [[ 42 325]]
#
#  [[ 37 321]]
#
#  [[ 34 312]]
#
#  [[ 34 298]]
#
#  [[ 33 288]]
#
#  [[ 30 274]]]
# 208
# 433
# Processing shapes from first video
# Drawing shape with points: [[[ 43 160]]
#
#  [[ 49 165]]
#
#  [[ 53 141]]
#
#  [[ 55 128]]
#
#  [[ 58 116]]
#
#  [[ 62  97]]
#
#  [[ 59 110]]
#
#  [[ 55 122]]
#
#  [[ 49 140]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 25 257]]
#
#  [[ 30 253]]
#
#  [[ 32 271]]
#
#  [[ 36 284]]
#
#  [[ 39 295]]
#
#  [[ 40 309]]
#
#  [[ 37 322]]
#
#  [[ 38 307]]
#
#  [[ 35 291]]
#
#  [[ 29 276]]]
# 209
# 434
# Processing shapes from first video
# Drawing shape with points: [[[ 45 161]]
#
#  [[ 51 166]]
#
#  [[ 54 143]]
#
#  [[ 57 130]]
#
#  [[ 60 117]]
#
#  [[ 64  99]]
#
#  [[ 60 111]]
#
#  [[ 57 124]]
#
#  [[ 51 142]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 25 252]]
#
#  [[ 32 250]]
#
#  [[ 31 271]]
#
#  [[ 34 287]]
#
#  [[ 40 298]]
#
#  [[ 43 311]]
#
#  [[ 38 322]]
#
#  [[ 40 312]]
#
#  [[ 36 300]]
#
#  [[ 32 291]]
#
#  [[ 26 271]]]
# 210
# 435
# Processing shapes from first video
# Drawing shape with points: [[[ 43 161]]
#
#  [[ 49 166]]
#
#  [[ 52 143]]
#
#  [[ 55 130]]
#
#  [[ 58 117]]
#
#  [[ 62  99]]
#
#  [[ 59 111]]
#
#  [[ 55 124]]
#
#  [[ 49 142]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 25 247]]
#
#  [[ 33 245]]
#
#  [[ 32 267]]
#
#  [[ 31 283]]
#
#  [[ 33 293]]
#
#  [[ 38 298]]
#
#  [[ 46 306]]
#
#  [[ 34 304]]
#
#  [[ 30 298]]
#
#  [[ 28 282]]
#
#  [[ 28 265]]]
# 211
# 436
# Processing shapes from first video
# Drawing shape with points: [[[ 43 161]]
#
#  [[ 49 166]]
#
#  [[ 52 143]]
#
#  [[ 55 130]]
#
#  [[ 58 117]]
#
#  [[ 62  99]]
#
#  [[ 59 111]]
#
#  [[ 55 124]]
#
#  [[ 49 142]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 24 245]]
#
#  [[ 30 241]]
#
#  [[ 33 265]]
#
#  [[ 32 282]]
#
#  [[ 32 297]]
#
#  [[ 37 306]]
#
#  [[ 31 304]]
#
#  [[ 29 293]]
#
#  [[ 29 276]]
#
#  [[ 28 266]]
#
#  [[ 24 254]]]
# 212
# 437
# Processing shapes from first video
# Drawing shape with points: [[[ 43 161]]
#
#  [[ 49 166]]
#
#  [[ 52 143]]
#
#  [[ 55 130]]
#
#  [[ 58 117]]
#
#  [[ 62  99]]
#
#  [[ 59 111]]
#
#  [[ 55 124]]
#
#  [[ 49 142]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 22 243]]
#
#  [[ 28 238]]
#
#  [[ 29 250]]
#
#  [[ 32 267]]
#
#  [[ 35 284]]
#
#  [[ 32 311]]
#
#  [[ 31 289]]
#
#  [[ 31 275]]
#
#  [[ 27 262]]]
# 213
# 438
# Processing shapes from first video
# Drawing shape with points: [[[ 43 161]]
#
#  [[ 49 166]]
#
#  [[ 52 143]]
#
#  [[ 55 130]]
#
#  [[ 58 117]]
#
#  [[ 62  99]]
#
#  [[ 59 111]]
#
#  [[ 55 124]]
#
#  [[ 49 142]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 23 238]]
#
#  [[ 30 237]]
#
#  [[ 29 260]]
#
#  [[ 32 269]]
#
#  [[ 35 280]]
#
#  [[ 37 298]]
#
#  [[ 32 304]]
#
#  [[ 33 297]]
#
#  [[ 35 286]]
#
#  [[ 29 273]]
#
#  [[ 23 254]]]
# 214
# 439
# Processing shapes from first video
# Drawing shape with points: [[[ 49 167]]
#
#  [[ 56 162]]
#
#  [[ 51 143]]
#
#  [[ 53 127]]
#
#  [[ 59 118]]
#
#  [[ 65 106]]
#
#  [[ 58 114]]
#
#  [[ 50 125]]
#
#  [[ 47 144]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 22 235]]
#
#  [[ 30 233]]
#
#  [[ 29 256]]
#
#  [[ 29 268]]
#
#  [[ 30 274]]
#
#  [[ 33 282]]
#
#  [[ 39 300]]
#
#  [[ 32 288]]
#
#  [[ 28 281]]
#
#  [[ 26 272]]
#
#  [[ 25 260]]
#
#  [[ 25 249]]]
# 215
# 440
# Processing shapes from first video
# Drawing shape with points: [[[ 52 201]]
#
#  [[ 58 200]]
#
#  [[ 56 182]]
#
#  [[ 56 161]]
#
#  [[ 53 146]]
#
#  [[ 51 130]]
#
#  [[ 50 141]]
#
#  [[ 53 158]]
#
#  [[ 53 180]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 22 232]]
#
#  [[ 29 228]]
#
#  [[ 30 245]]
#
#  [[ 29 262]]
#
#  [[ 28 275]]
#
#  [[ 30 282]]
#
#  [[ 35 290]]
#
#  [[ 29 290]]
#
#  [[ 26 284]]
#
#  [[ 26 275]]
#
#  [[ 26 262]]
#
#  [[ 25 250]]
#
#  [[ 23 241]]]
# 216
# 441
# Processing shapes from first video
# Drawing shape with points: [[[ 51 226]]
#
#  [[ 58 224]]
#
#  [[ 56 207]]
#
#  [[ 56 185]]
#
#  [[ 55 168]]
#
#  [[ 54 155]]
#
#  [[ 52 165]]
#
#  [[ 53 183]]
#
#  [[ 53 204]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 20 229]]
#
#  [[ 28 224]]
#
#  [[ 28 242]]
#
#  [[ 31 257]]
#
#  [[ 30 276]]
#
#  [[ 30 284]]
#
#  [[ 33 301]]
#
#  [[ 27 291]]
#
#  [[ 28 271]]
#
#  [[ 28 258]]
#
#  [[ 25 249]]]
# 217
# 442
# Processing shapes from first video
# Drawing shape with points: [[[ 50 234]]
#
#  [[ 57 233]]
#
#  [[ 56 215]]
#
#  [[ 55 194]]
#
#  [[ 54 177]]
#
#  [[ 53 164]]
#
#  [[ 51 174]]
#
#  [[ 52 191]]
#
#  [[ 52 213]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 19 223]]
#
#  [[ 27 221]]
#
#  [[ 27 237]]
#
#  [[ 29 248]]
#
#  [[ 33 260]]
#
#  [[ 33 273]]
#
#  [[ 31 284]]
#
#  [[ 27 290]]
#
#  [[ 29 278]]
#
#  [[ 30 273]]
#
#  [[ 29 267]]
#
#  [[ 28 260]]
#
#  [[ 25 252]]
#
#  [[ 21 241]]]
# 218
# 443
# Processing shapes from first video
# Drawing shape with points: [[[ 51 237]]
#
#  [[ 58 236]]
#
#  [[ 56 218]]
#
#  [[ 54 194]]
#
#  [[ 52 179]]
#
#  [[ 51 165]]
#
#  [[ 51 174]]
#
#  [[ 52 192]]
#
#  [[ 53 216]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 19 221]]
#
#  [[ 27 220]]
#
#  [[ 27 235]]
#
#  [[ 27 244]]
#
#  [[ 27 253]]
#
#  [[ 29 260]]
#
#  [[ 32 267]]
#
#  [[ 33 276]]
#
#  [[ 30 288]]
#
#  [[ 31 278]]
#
#  [[ 29 268]]
#
#  [[ 26 259]]
#
#  [[ 23 246]]
#
#  [[ 22 234]]]
# 219
# 444
# Processing shapes from first video
# Drawing shape with points: [[[ 52 239]]
#
#  [[ 59 238]]
#
#  [[ 57 220]]
#
#  [[ 55 196]]
#
#  [[ 53 180]]
#
#  [[ 52 166]]
#
#  [[ 52 176]]
#
#  [[ 52 194]]
#
#  [[ 53 218]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 18 219]]
#
#  [[ 27 216]]
#
#  [[ 27 229]]
#
#  [[ 27 240]]
#
#  [[ 27 254]]
#
#  [[ 27 262]]
#
#  [[ 31 269]]
#
#  [[ 35 278]]
#
#  [[ 28 276]]
#
#  [[ 25 266]]
#
#  [[ 22 252]]
#
#  [[ 23 242]]]
# 220
# 445
# Processing shapes from first video
# Drawing shape with points: [[[ 52 241]]
#
#  [[ 59 240]]
#
#  [[ 57 222]]
#
#  [[ 55 198]]
#
#  [[ 53 182]]
#
#  [[ 50 165]]
#
#  [[ 50 176]]
#
#  [[ 51 195]]
#
#  [[ 53 220]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 19 217]]
#
#  [[ 26 214]]
#
#  [[ 26 227]]
#
#  [[ 28 245]]
#
#  [[ 27 259]]
#
#  [[ 27 266]]
#
#  [[ 28 272]]
#
#  [[ 32 278]]
#
#  [[ 25 276]]
#
#  [[ 24 260]]
#
#  [[ 25 251]]
#
#  [[ 24 237]]
#
#  [[ 22 230]]]
# 221
# 446
# Processing shapes from first video
# Drawing shape with points: [[[ 52 245]]
#
#  [[ 61 243]]
#
#  [[ 57 226]]
#
#  [[ 55 202]]
#
#  [[ 53 187]]
#
#  [[ 50 169]]
#
#  [[ 50 180]]
#
#  [[ 51 199]]
#
#  [[ 53 224]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 19 217]]
#
#  [[ 26 214]]
#
#  [[ 26 227]]
#
#  [[ 28 245]]
#
#  [[ 27 259]]
#
#  [[ 27 266]]
#
#  [[ 28 272]]
#
#  [[ 32 278]]
#
#  [[ 25 276]]
#
#  [[ 24 260]]
#
#  [[ 25 251]]
#
#  [[ 24 237]]
#
#  [[ 22 230]]]
# 222
# 447
# Processing shapes from first video
# Drawing shape with points: [[[ 52 245]]
#
#  [[ 61 243]]
#
#  [[ 57 226]]
#
#  [[ 55 202]]
#
#  [[ 53 187]]
#
#  [[ 50 169]]
#
#  [[ 50 180]]
#
#  [[ 51 199]]
#
#  [[ 53 224]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 19 207]]
#
#  [[ 26 207]]
#
#  [[ 26 216]]
#
#  [[ 26 227]]
#
#  [[ 25 235]]
#
#  [[ 28 245]]
#
#  [[ 29 254]]
#
#  [[ 31 265]]
#
#  [[ 26 278]]
#
#  [[ 28 262]]
#
#  [[ 26 255]]
#
#  [[ 24 241]]
#
#  [[ 21 225]]]
# 223
# 448
# Processing shapes from first video
# Drawing shape with points: [[[ 52 246]]
#
#  [[ 61 243]]
#
#  [[ 57 227]]
#
#  [[ 53 201]]
#
#  [[ 52 187]]
#
#  [[ 48 168]]
#
#  [[ 50 180]]
#
#  [[ 51 200]]
#
#  [[ 53 224]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 19 207]]
#
#  [[ 25 205]]
#
#  [[ 26 224]]
#
#  [[ 26 236]]
#
#  [[ 27 245]]
#
#  [[ 28 254]]
#
#  [[ 30 267]]
#
#  [[ 26 280]]
#
#  [[ 28 264]]
#
#  [[ 25 254]]
#
#  [[ 23 237]]
#
#  [[ 22 226]]]
# 224
# 449
# Processing shapes from first video
# Drawing shape with points: [[[ 52 246]]
#
#  [[ 61 243]]
#
#  [[ 57 227]]
#
#  [[ 53 201]]
#
#  [[ 52 187]]
#
#  [[ 48 168]]
#
#  [[ 50 180]]
#
#  [[ 51 200]]
#
#  [[ 53 224]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 19 205]]
#
#  [[ 26 204]]
#
#  [[ 26 245]]
#
#  [[ 30 278]]
#
#  [[ 25 260]]
#
#  [[ 22 222]]]
# 225
# 450
# Processing shapes from first video
# Drawing shape with points: [[[ 54 248]]
#
#  [[ 60 245]]
#
#  [[ 57 228]]
#
#  [[ 53 202]]
#
#  [[ 51 188]]
#
#  [[ 48 169]]
#
#  [[ 49 182]]
#
#  [[ 50 201]]
#
#  [[ 53 226]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 19 205]]
#
#  [[ 26 204]]
#
#  [[ 26 245]]
#
#  [[ 30 278]]
#
#  [[ 25 260]]
#
#  [[ 22 222]]]
# 226
# 451
# Processing shapes from first video
# Drawing shape with points: [[[ 53 249]]
#
#  [[ 60 247]]
#
#  [[ 57 228]]
#
#  [[ 57 209]]
#
#  [[ 54 196]]
#
#  [[ 46 185]]
#
#  [[ 52 198]]
#
#  [[ 54 209]]
#
#  [[ 53 226]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 19 205]]
#
#  [[ 26 204]]
#
#  [[ 26 245]]
#
#  [[ 27 276]]
#
#  [[ 25 260]]
#
#  [[ 23 227]]]
# 227
# 452
# Processing shapes from first video
# Drawing shape with points: [[[ 61 282]]
#
#  [[ 69 279]]
#
#  [[ 65 260]]
#
#  [[ 59 243]]
#
#  [[ 55 229]]
#
#  [[ 52 215]]
#
#  [[ 52 229]]
#
#  [[ 57 244]]
#
#  [[ 61 258]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 19 204]]
#
#  [[ 25 203]]
#
#  [[ 26 244]]
#
#  [[ 26 275]]
#
#  [[ 24 259]]
#
#  [[ 23 226]]]
# 228
# 453
# Processing shapes from first video
# Drawing shape with points: [[[ 67 308]]
#
#  [[ 74 303]]
#
#  [[ 68 282]]
#
#  [[ 64 268]]
#
#  [[ 63 247]]
#
#  [[ 59 238]]
#
#  [[ 60 248]]
#
#  [[ 62 270]]
#
#  [[ 64 283]]]
# Processing shapes from second video
# Drawing shape with points: [[[ 19 204]]
#
#  [[ 25 203]]
#
#  [[ 26 244]]
#
#  [[ 26 275]]
#
#  [[ 24 259]]
#
#  [[ 23 226]]]
